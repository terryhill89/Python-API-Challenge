# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Import API key
from config import api_key 

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 622

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units ="imperial"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']["lat"]
        city_lng = city_weather['coord']["lon"]
        city_max_temp = city_weather['main']["temp_max"]
        city_humidity = city_weather['main']["humidity"]
        city_clouds = city_weather['clouds']["all"]
        city_wind = city_weather['wind']["speed"]
        city_country = city_weather['sys']["country"]
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vilhena
# Processing Record 2 of Set 1 | khatanga
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | fairlie
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 9 of Set 1 | chuy
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | xining
# Processing Record 14 of Set 1 | kavieng
# Processing Record 15 of Set 1 | whitehorse
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | manokwari
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | narsaq
# Processing Record 21 of Set 1 | tarko-sale
# Processing Record 22 of Set 1 | upernavik
# Processing Record 23 of Set 1 | baruun-urt
# Processing Record 24 of Set 1 | port hardy
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | pangnirtung
# Processing Record 27 of Set 1 | te anau
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | cherskiy
# Processing Record 30 of Set 1 | tasiilaq
# Processing Record 31 of Set 1 | bonavista
# Processing Record 32 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 1 | cabo san lucas
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | husavik
# Processing Record 36 of Set 1 | los llanos de aridane
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | saskylakh
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | ponta do sol
# Processing Record 41 of Set 1 | souillac
# Processing Record 42 of Set 1 | ossora
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | cururupu
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | lata
# Processing Record 47 of Set 1 | fortuna
# Processing Record 48 of Set 1 | slonim
# Processing Record 49 of Set 1 | kaitangata
# Processing Record 50 of Set 1 | naze
# Processing Record 0 of Set 2 | bredasdorp
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 2 | new norfolk
# Processing Record 4 of Set 2 | asayita
# City not found. Skipping...
# Processing Record 5 of Set 2 | grindavik
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | vorobyevka
# Processing Record 8 of Set 2 | hilo
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | mount isa
# Processing Record 11 of Set 2 | kirovskiy
# Processing Record 12 of Set 2 | roma
# Processing Record 13 of Set 2 | harlingen
# Processing Record 14 of Set 2 | ust-kuyga
# Processing Record 15 of Set 2 | caraquet
# Processing Record 16 of Set 2 | fuerte olimpo
# Processing Record 17 of Set 2 | melfi
# Processing Record 18 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | bambanglipuro
# Processing Record 21 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 2 | clyde river
# Processing Record 23 of Set 2 | salinas
# Processing Record 24 of Set 2 | saint-augustin
# Processing Record 25 of Set 2 | auki
# Processing Record 26 of Set 2 | zhanaozen
# Processing Record 27 of Set 2 | rikitea
# Processing Record 28 of Set 2 | hobart
# Processing Record 29 of Set 2 | faanui
# Processing Record 30 of Set 2 | buraydah
# Processing Record 31 of Set 2 | katsuura
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | talnakh
# Processing Record 34 of Set 2 | san cristobal
# Processing Record 35 of Set 2 | castro
# Processing Record 36 of Set 2 | bathsheba
# Processing Record 37 of Set 2 | jamestown
# Processing Record 38 of Set 2 | provideniya
# Processing Record 39 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 2 | imbituba
# Processing Record 41 of Set 2 | asfi
# Processing Record 42 of Set 2 | caravelas
# Processing Record 43 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 2 | chyhyryn
# Processing Record 45 of Set 2 | obo
# Processing Record 46 of Set 2 | ballina
# Processing Record 47 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 2 | novobiryusinskiy
# Processing Record 49 of Set 2 | shumskiy
# Processing Record 0 of Set 3 | labytnangi
# Processing Record 1 of Set 3 | caramay
# Processing Record 2 of Set 3 | georgetown
# Processing Record 3 of Set 3 | turkistan
# Processing Record 4 of Set 3 | yining
# Processing Record 5 of Set 3 | ahuimanu
# Processing Record 6 of Set 3 | yulara
# Processing Record 7 of Set 3 | honningsvag
# Processing Record 8 of Set 3 | puri
# Processing Record 9 of Set 3 | hambantota
# Processing Record 10 of Set 3 | kaveripattinam
# Processing Record 11 of Set 3 | sioux lookout
# Processing Record 12 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 3 | haflong
# Processing Record 14 of Set 3 | juneau
# Processing Record 15 of Set 3 | qaanaaq
# Processing Record 16 of Set 3 | medicine hat
# Processing Record 17 of Set 3 | vaini
# Processing Record 18 of Set 3 | butaritari
# Processing Record 19 of Set 3 | catio
# Processing Record 20 of Set 3 | victoria
# Processing Record 21 of Set 3 | iisalmi
# Processing Record 22 of Set 3 | virginia beach
# Processing Record 23 of Set 3 | isla mujeres
# Processing Record 24 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 3 | catalina
# Processing Record 26 of Set 3 | sobolevo
# Processing Record 27 of Set 3 | ambon
# Processing Record 28 of Set 3 | salto
# Processing Record 29 of Set 3 | kargopol
# Processing Record 30 of Set 3 | tuktoyaktuk
# Processing Record 31 of Set 3 | lebu
# Processing Record 32 of Set 3 | port elizabeth
# Processing Record 33 of Set 3 | vostok
# Processing Record 34 of Set 3 | bethel
# Processing Record 35 of Set 3 | severo-kurilsk
# Processing Record 36 of Set 3 | kodiak
# Processing Record 37 of Set 3 | partizansk
# Processing Record 38 of Set 3 | hope
# Processing Record 39 of Set 3 | sitka
# Processing Record 40 of Set 3 | sompeta
# Processing Record 41 of Set 3 | cidreira
# Processing Record 42 of Set 3 | gander
# Processing Record 43 of Set 3 | sao filipe
# Processing Record 44 of Set 3 | contai
# Processing Record 45 of Set 3 | aykhal
# Processing Record 46 of Set 3 | kenai
# Processing Record 47 of Set 3 | nanortalik
# Processing Record 48 of Set 3 | isangel
# Processing Record 49 of Set 3 | pemba
# Processing Record 0 of Set 4 | coihueco
# Processing Record 1 of Set 4 | bengkulu
# Processing Record 2 of Set 4 | palauig
# Processing Record 3 of Set 4 | chokurdakh
# Processing Record 4 of Set 4 | nandyal
# Processing Record 5 of Set 4 | thompson
# Processing Record 6 of Set 4 | alice springs
# Processing Record 7 of Set 4 | klyuchi
# Processing Record 8 of Set 4 | alofi
# Processing Record 9 of Set 4 | ahipara
# Processing Record 10 of Set 4 | ust-shonosha
# Processing Record 11 of Set 4 | ust-tsilma
# Processing Record 12 of Set 4 | carnarvon
# Processing Record 13 of Set 4 | dudinka
# Processing Record 14 of Set 4 | galesong
# Processing Record 15 of Set 4 | sulangan
# Processing Record 16 of Set 4 | myre
# Processing Record 17 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 4 | quatre cocos
# Processing Record 20 of Set 4 | rongcheng
# Processing Record 21 of Set 4 | tuatapere
# Processing Record 22 of Set 4 | arles
# Processing Record 23 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 25 of Set 4 | umm kaddadah
# Processing Record 26 of Set 4 | rawson
# Processing Record 27 of Set 4 | iqaluit
# Processing Record 28 of Set 4 | airai
# Processing Record 29 of Set 4 | marsa matruh
# Processing Record 30 of Set 4 | natal
# Processing Record 31 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 32 of Set 4 | broken hill
# Processing Record 33 of Set 4 | padang
# Processing Record 34 of Set 4 | erzin
# Processing Record 35 of Set 4 | mao
# Processing Record 36 of Set 4 | kharabali
# Processing Record 37 of Set 4 | dogondoutchi
# Processing Record 38 of Set 4 | namatanai
# Processing Record 39 of Set 4 | puerto escondido
# Processing Record 40 of Set 4 | baykit
# Processing Record 41 of Set 4 | ledyard
# Processing Record 42 of Set 4 | bandarbeyla
# Processing Record 43 of Set 4 | ostrovnoy
# Processing Record 44 of Set 4 | kushiro
# Processing Record 45 of Set 4 | cooma
# Processing Record 46 of Set 4 | kalaleh
# Processing Record 47 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 4 | smithers
# Processing Record 49 of Set 4 | mount gambier
# Processing Record 0 of Set 5 | viking
# Processing Record 1 of Set 5 | stoyba
# City not found. Skipping...
# Processing Record 2 of Set 5 | nushki
# Processing Record 3 of Set 5 | jieshi
# Processing Record 4 of Set 5 | maniitsoq
# Processing Record 5 of Set 5 | utete
# Processing Record 6 of Set 5 | cayenne
# Processing Record 7 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 5 | taywarah
# Processing Record 9 of Set 5 | skibbereen
# Processing Record 10 of Set 5 | mamit
# Processing Record 11 of Set 5 | vardo
# Processing Record 12 of Set 5 | cacoal
# Processing Record 13 of Set 5 | burns lake
# Processing Record 14 of Set 5 | betioky
# Processing Record 15 of Set 5 | mareeba
# Processing Record 16 of Set 5 | balinad
# Processing Record 17 of Set 5 | nabire
# Processing Record 18 of Set 5 | jiuquan
# Processing Record 19 of Set 5 | shimoda
# Processing Record 20 of Set 5 | okhotsk
# Processing Record 21 of Set 5 | ancud
# Processing Record 22 of Set 5 | vila velha
# Processing Record 23 of Set 5 | gat
# Processing Record 24 of Set 5 | nuuk
# Processing Record 25 of Set 5 | grand gaube
# Processing Record 26 of Set 5 | broome
# Processing Record 27 of Set 5 | faya
# Processing Record 28 of Set 5 | ottawa
# Processing Record 29 of Set 5 | salalah
# Processing Record 30 of Set 5 | gamba
# Processing Record 31 of Set 5 | sovetskiy
# Processing Record 32 of Set 5 | nikolskoye
# Processing Record 33 of Set 5 | cap malheureux
# Processing Record 34 of Set 5 | chapais
# Processing Record 35 of Set 5 | rochegda
# Processing Record 36 of Set 5 | aklavik
# Processing Record 37 of Set 5 | teahupoo
# Processing Record 38 of Set 5 | birjand
# Processing Record 39 of Set 5 | preobrazheniye
# Processing Record 40 of Set 5 | half moon bay
# Processing Record 41 of Set 5 | kaoma
# Processing Record 42 of Set 5 | port lincoln
# Processing Record 43 of Set 5 | ilebo
# Processing Record 44 of Set 5 | bilma
# Processing Record 45 of Set 5 | belle fourche
# Processing Record 46 of Set 5 | maarianhamina
# Processing Record 47 of Set 5 | male
# Processing Record 48 of Set 5 | yar-sale
# Processing Record 49 of Set 5 | alice town
# Processing Record 0 of Set 6 | yatou
# Processing Record 1 of Set 6 | pisco
# Processing Record 2 of Set 6 | matagami
# Processing Record 3 of Set 6 | kristiinankaupunki
# Processing Record 4 of Set 6 | sokoni
# Processing Record 5 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 6 of Set 6 | coihaique
# Processing Record 7 of Set 6 | geraldton
# Processing Record 8 of Set 6 | vaitape
# Processing Record 9 of Set 6 | divo
# Processing Record 10 of Set 6 | brae
# Processing Record 11 of Set 6 | saint-philippe
# Processing Record 12 of Set 6 | huarmey
# Processing Record 13 of Set 6 | andenes
# Processing Record 14 of Set 6 | kruisfontein
# Processing Record 15 of Set 6 | yaan
# Processing Record 16 of Set 6 | ilulissat
# Processing Record 17 of Set 6 | oranjemund
# Processing Record 18 of Set 6 | santiago del estero
# Processing Record 19 of Set 6 | harper
# Processing Record 20 of Set 6 | agadez
# Processing Record 21 of Set 6 | portland
# Processing Record 22 of Set 6 | norman wells
# Processing Record 23 of Set 6 | lahij
# Processing Record 24 of Set 6 | pervomayskoye
# Processing Record 25 of Set 6 | san policarpo
# Processing Record 26 of Set 6 | lompoc
# Processing Record 27 of Set 6 | samarkand
# Processing Record 28 of Set 6 | xichang
# Processing Record 29 of Set 6 | tornio
# Processing Record 30 of Set 6 | unai
# Processing Record 31 of Set 6 | saint george
# Processing Record 32 of Set 6 | necochea
# Processing Record 33 of Set 6 | guanica
# Processing Record 34 of Set 6 | lorengau
# Processing Record 35 of Set 6 | guadalajara
# Processing Record 36 of Set 6 | methoni
# Processing Record 37 of Set 6 | turukhansk
# Processing Record 38 of Set 6 | hay river
# Processing Record 39 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 40 of Set 6 | talaya
# Processing Record 41 of Set 6 | ishigaki
# Processing Record 42 of Set 6 | noyabrsk
# Processing Record 43 of Set 6 | arraial do cabo
# Processing Record 44 of Set 6 | devils lake
# Processing Record 45 of Set 6 | kakching
# Processing Record 46 of Set 6 | vanimo
# Processing Record 47 of Set 6 | kardla
# Processing Record 48 of Set 6 | margate
# Processing Record 49 of Set 6 | cozumel
# Processing Record 0 of Set 7 | vestmannaeyjar
# Processing Record 1 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 7 | churapcha
# Processing Record 3 of Set 7 | ikalamavony
# Processing Record 4 of Set 7 | nemuro
# Processing Record 5 of Set 7 | synya
# Processing Record 6 of Set 7 | labuhan
# Processing Record 7 of Set 7 | bosaso
# Processing Record 8 of Set 7 | urubicha
# Processing Record 9 of Set 7 | yeppoon
# Processing Record 10 of Set 7 | yanam
# Processing Record 11 of Set 7 | tacoronte
# Processing Record 12 of Set 7 | constitucion
# Processing Record 13 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 7 | basco
# Processing Record 15 of Set 7 | iwanai
# Processing Record 16 of Set 7 | koraput
# Processing Record 17 of Set 7 | bergama
# Processing Record 18 of Set 7 | bouloupari
# Processing Record 19 of Set 7 | severnyy-kospashskiy
# Processing Record 20 of Set 7 | ordzhonikidze
# Processing Record 21 of Set 7 | viedma
# Processing Record 22 of Set 7 | touros
# Processing Record 23 of Set 7 | denpasar
# Processing Record 24 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 7 | boa vista
# Processing Record 26 of Set 7 | pevek
# Processing Record 27 of Set 7 | avera
# Processing Record 28 of Set 7 | visnes
# Processing Record 29 of Set 7 | rincon
# Processing Record 30 of Set 7 | kalmunai
# Processing Record 31 of Set 7 | anadyr
# Processing Record 32 of Set 7 | carbonear
# Processing Record 33 of Set 7 | cam ranh
# Processing Record 34 of Set 7 | erdenet
# Processing Record 35 of Set 7 | adana
# Processing Record 36 of Set 7 | codrington
# Processing Record 37 of Set 7 | butte
# Processing Record 38 of Set 7 | emerald
# Processing Record 39 of Set 7 | gravdal
# Processing Record 40 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 7 | praia
# Processing Record 42 of Set 7 | rizhao
# Processing Record 43 of Set 7 | waling
# Processing Record 44 of Set 7 | acapulco
# Processing Record 45 of Set 7 | beidao
# Processing Record 46 of Set 7 | vrangel
# Processing Record 47 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 7 | kuching
# Processing Record 49 of Set 7 | barra
# Processing Record 0 of Set 8 | nouakchott
# Processing Record 1 of Set 8 | baturaja
# Processing Record 2 of Set 8 | nago
# Processing Record 3 of Set 8 | batagay-alyta
# Processing Record 4 of Set 8 | luderitz
# Processing Record 5 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 8 | antofagasta
# Processing Record 7 of Set 8 | akdepe
# Processing Record 8 of Set 8 | hofn
# Processing Record 9 of Set 8 | sibolga
# Processing Record 10 of Set 8 | mar del plata
# Processing Record 11 of Set 8 | bereda
# Processing Record 12 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 13 of Set 8 | krasnyy kholm
# Processing Record 14 of Set 8 | gurskoye
# City not found. Skipping...
# Processing Record 15 of Set 8 | wahiawa
# Processing Record 16 of Set 8 | trairi
# Processing Record 17 of Set 8 | ketchikan
# Processing Record 18 of Set 8 | hami
# Processing Record 19 of Set 8 | cabedelo
# Processing Record 20 of Set 8 | bireun
# Processing Record 21 of Set 8 | port hawkesbury
# Processing Record 22 of Set 8 | kasongo-lunda
# Processing Record 23 of Set 8 | dodoma
# Processing Record 24 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 25 of Set 8 | qaqortoq
# Processing Record 26 of Set 8 | sao felix do xingu
# Processing Record 27 of Set 8 | orlik
# Processing Record 28 of Set 8 | kulhudhuffushi
# Processing Record 29 of Set 8 | doha
# Processing Record 30 of Set 8 | salair
# Processing Record 31 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 8 | alamosa
# Processing Record 33 of Set 8 | opuwo
# Processing Record 34 of Set 8 | komsomolets
# Processing Record 35 of Set 8 | dondo
# Processing Record 36 of Set 8 | mahebourg
# Processing Record 37 of Set 8 | eqbaliyeh
# Processing Record 38 of Set 8 | bilibino
# Processing Record 39 of Set 8 | san clemente
# Processing Record 40 of Set 8 | svetlogorsk
# Processing Record 41 of Set 8 | giaginskaya
# Processing Record 42 of Set 8 | kaseda
# Processing Record 43 of Set 8 | naron
# Processing Record 44 of Set 8 | phuket
# Processing Record 45 of Set 8 | chimbote
# Processing Record 46 of Set 8 | kailua
# Processing Record 47 of Set 8 | alta floresta
# Processing Record 48 of Set 8 | pointe michel
# Processing Record 49 of Set 8 | dauriya
# Processing Record 0 of Set 9 | xai-xai
# Processing Record 1 of Set 9 | salisbury
# Processing Record 2 of Set 9 | lima
# Processing Record 3 of Set 9 | leningradskiy
# Processing Record 4 of Set 9 | nizwa
# Processing Record 5 of Set 9 | ponta pora
# Processing Record 6 of Set 9 | west bay
# Processing Record 7 of Set 9 | comodoro rivadavia
# Processing Record 8 of Set 9 | roald
# Processing Record 9 of Set 9 | beyneu
# Processing Record 10 of Set 9 | dunedin
# Processing Record 11 of Set 9 | neiafu
# Processing Record 12 of Set 9 | marawi
# Processing Record 13 of Set 9 | gizo
# Processing Record 14 of Set 9 | jaguaruana
# Processing Record 15 of Set 9 | mnogovershinnyy
# Processing Record 16 of Set 9 | guerrero negro
# Processing Record 17 of Set 9 | vinh
# Processing Record 18 of Set 9 | pacifica
# Processing Record 19 of Set 9 | wajid
# Processing Record 20 of Set 9 | sur
# Processing Record 21 of Set 9 | itum-kale
# Processing Record 22 of Set 9 | metro
# Processing Record 23 of Set 9 | lidkoping
# Processing Record 24 of Set 9 | la ronge
# Processing Record 25 of Set 9 | nouadhibou
# Processing Record 26 of Set 9 | nipawin
# Processing Record 27 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 28 of Set 9 | ialibu
# Processing Record 29 of Set 9 | tchibanga
# Processing Record 30 of Set 9 | pacific grove
# Processing Record 31 of Set 9 | christchurch
# Processing Record 32 of Set 9 | manaus
# Processing Record 33 of Set 9 | klaksvik
# Processing Record 34 of Set 9 | racale
# Processing Record 35 of Set 9 | zharkent
# Processing Record 36 of Set 9 | krasnoarmeysk
# Processing Record 37 of Set 9 | san borja
# Processing Record 38 of Set 9 | goderich
# Processing Record 39 of Set 9 | poronaysk
# Processing Record 40 of Set 9 | ayan
# Processing Record 41 of Set 9 | esil
# Processing Record 42 of Set 9 | lasa
# Processing Record 43 of Set 9 | lensk
# Processing Record 44 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 45 of Set 9 | garchitorena
# Processing Record 46 of Set 9 | fougeres
# Processing Record 47 of Set 9 | merauke
# Processing Record 48 of Set 9 | longyearbyen
# Processing Record 49 of Set 9 | one hundred mile house
# City not found. Skipping...
# Processing Record 0 of Set 10 | aseri
# Processing Record 1 of Set 10 | agirish
# Processing Record 2 of Set 10 | north bend
# Processing Record 3 of Set 10 | novyy urengoy
# Processing Record 4 of Set 10 | kahului
# Processing Record 5 of Set 10 | dukhovshchina
# Processing Record 6 of Set 10 | zhezkazgan
# Processing Record 7 of Set 10 | luwuk
# Processing Record 8 of Set 10 | nome
# Processing Record 9 of Set 10 | seoul
# Processing Record 10 of Set 10 | karatu
# Processing Record 11 of Set 10 | ribeira grande
# Processing Record 12 of Set 10 | dauphin
# Processing Record 13 of Set 10 | visby
# Processing Record 14 of Set 10 | vila franca do campo
# Processing Record 15 of Set 10 | mecca
# Processing Record 16 of Set 10 | port keats
# Processing Record 17 of Set 10 | kilindoni
# Processing Record 18 of Set 10 | morgan city
# Processing Record 19 of Set 10 | george
# Processing Record 20 of Set 10 | liniere
# City not found. Skipping...
# Processing Record 21 of Set 10 | barceloneta
# Processing Record 22 of Set 10 | bosilegrad
# Processing Record 23 of Set 10 | burnie
# Processing Record 24 of Set 10 | sunbury
# Processing Record 25 of Set 10 | saldanha
# Processing Record 26 of Set 10 | beringovskiy
# Processing Record 27 of Set 10 | samatau
# City not found. Skipping...
# Processing Record 28 of Set 10 | along
# Processing Record 29 of Set 10 | burica
# City not found. Skipping...
# Processing Record 30 of Set 10 | jhunjhunun
# Processing Record 31 of Set 10 | aripuana
# Processing Record 32 of Set 10 | sakakah
# Processing Record 33 of Set 10 | tomatlan
# Processing Record 34 of Set 10 | bundaberg
# Processing Record 35 of Set 10 | belaya gora
# Processing Record 36 of Set 10 | peleduy
# Processing Record 37 of Set 10 | vysokogornyy
# Processing Record 38 of Set 10 | santander jimenez
# Processing Record 39 of Set 10 | nalut
# Processing Record 40 of Set 10 | kaeo
# Processing Record 41 of Set 10 | mokhsogollokh
# Processing Record 42 of Set 10 | the valley
# Processing Record 43 of Set 10 | katsiveli
# City not found. Skipping...
# Processing Record 44 of Set 10 | arivonimamo
# Processing Record 45 of Set 10 | torbay
# Processing Record 46 of Set 10 | namibe
# Processing Record 47 of Set 10 | kamenka
# Processing Record 48 of Set 10 | richards bay
# Processing Record 49 of Set 10 | maham
# Processing Record 0 of Set 11 | ambulu
# Processing Record 1 of Set 11 | dingle
# Processing Record 2 of Set 11 | eseka
# Processing Record 3 of Set 11 | chincha alta
# Processing Record 4 of Set 11 | kingman
# Processing Record 5 of Set 11 | mopipi
# Processing Record 6 of Set 11 | mwinilunga
# Processing Record 7 of Set 11 | high level
# Processing Record 8 of Set 11 | korla
# Processing Record 9 of Set 11 | zhigansk
# Processing Record 10 of Set 11 | kenora
# Processing Record 11 of Set 11 | robertsport
# Processing Record 12 of Set 11 | olafsvik
# Processing Record 13 of Set 11 | puquio
# Processing Record 14 of Set 11 | hobyo
# Processing Record 15 of Set 11 | fort nelson
# Processing Record 16 of Set 11 | puerto triunfo
# Processing Record 17 of Set 11 | bambous virieux
# Processing Record 18 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 11 | esperance
# Processing Record 20 of Set 11 | conceicao da barra
# Processing Record 21 of Set 11 | saint-georges
# Processing Record 22 of Set 11 | severomorsk
# Processing Record 23 of Set 11 | zhaotong
# Processing Record 24 of Set 11 | kalyazin
# Processing Record 25 of Set 11 | college
# Processing Record 26 of Set 11 | tezu
# Processing Record 27 of Set 11 | pozo colorado
# Processing Record 28 of Set 11 | kiama
# Processing Record 29 of Set 11 | verkhnevilyuysk
# Processing Record 30 of Set 11 | lagoa
# Processing Record 31 of Set 11 | patitirion
# Processing Record 32 of Set 11 | den helder
# Processing Record 33 of Set 11 | ust-nera
# Processing Record 34 of Set 11 | pedasi
# Processing Record 35 of Set 11 | mehamn
# Processing Record 36 of Set 11 | karratha
# Processing Record 37 of Set 11 | wanning
# Processing Record 38 of Set 11 | kloulklubed
# Processing Record 39 of Set 11 | takoradi
# Processing Record 40 of Set 11 | flin flon
# Processing Record 41 of Set 11 | rosarito
# Processing Record 42 of Set 11 | colares
# Processing Record 43 of Set 11 | cortez
# Processing Record 44 of Set 11 | kluang
# Processing Record 45 of Set 11 | dhidhdhoo
# Processing Record 46 of Set 11 | terrace
# Processing Record 47 of Set 11 | asau
# Processing Record 48 of Set 11 | duncanville
# Processing Record 49 of Set 11 | jardim
# Processing Record 0 of Set 12 | paamiut
# Processing Record 1 of Set 12 | macedo de cavaleiros
# Processing Record 2 of Set 12 | njombe
# Processing Record 3 of Set 12 | makakilo city
# Processing Record 4 of Set 12 | tarakan
# Processing Record 5 of Set 12 | bianzhuang
# Processing Record 6 of Set 12 | nioro
# Processing Record 7 of Set 12 | san patricio
# Processing Record 8 of Set 12 | shelkovskaya
# Processing Record 9 of Set 12 | beshpagir
# Processing Record 10 of Set 12 | naryan-mar
# Processing Record 11 of Set 12 | saint-joseph
# Processing Record 12 of Set 12 | omboue
# Processing Record 13 of Set 12 | ngunguru
# Processing Record 14 of Set 12 | nanzhang
# Processing Record 15 of Set 12 | beloha
# Processing Record 16 of Set 12 | kaspiyskiy
# Processing Record 17 of Set 12 | balabac
# Processing Record 18 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 19 of Set 12 | sunrise manor
# Processing Record 20 of Set 12 | jacksonville
# Processing Record 21 of Set 12 | hillsborough
# Processing Record 22 of Set 12 | nayoro
# Processing Record 23 of Set 12 | ciudad bolivar
# Processing Record 24 of Set 12 | tamiahua
# Processing Record 25 of Set 12 | mykolayivka
# Processing Record 26 of Set 12 | anito
# Processing Record 27 of Set 12 | jarinu
# Processing Record 28 of Set 12 | verkhnetulomskiy
# Processing Record 29 of Set 12 | ornskoldsvik
# Processing Record 30 of Set 12 | laval
# Processing Record 31 of Set 12 | olga
# Processing Record 32 of Set 12 | chumikan
# Processing Record 33 of Set 12 | tucuman
# Processing Record 34 of Set 12 | batticaloa
# Processing Record 35 of Set 12 | chermoz
# Processing Record 36 of Set 12 | kalianget
# Processing Record 37 of Set 12 | fenoarivo
# Processing Record 38 of Set 12 | vera cruz
# Processing Record 39 of Set 12 | pingliang
# Processing Record 40 of Set 12 | kasungu
# Processing Record 41 of Set 12 | teguldet
# Processing Record 42 of Set 12 | kagoro
# Processing Record 43 of Set 12 | abonnema
# Processing Record 44 of Set 12 | glubokoe
# City not found. Skipping...
# Processing Record 45 of Set 12 | russell
# Processing Record 46 of Set 12 | freeport
# Processing Record 47 of Set 12 | invermere
# Processing Record 48 of Set 12 | riachao
# Processing Record 49 of Set 12 | hamilton
# Processing Record 0 of Set 13 | aranos
# Processing Record 1 of Set 13 | northam
# Processing Record 2 of Set 13 | moree
# Processing Record 3 of Set 13 | besancon
# Processing Record 4 of Set 13 | hervey bay
# Processing Record 5 of Set 13 | viransehir
# Processing Record 6 of Set 13 | chickasha
# Processing Record 7 of Set 13 | lipin bor
# Processing Record 8 of Set 13 | bani walid
# Processing Record 9 of Set 13 | palizada
# Processing Record 10 of Set 13 | matara
# Processing Record 11 of Set 13 | trogir
# Processing Record 12 of Set 13 | homer
# Processing Record 13 of Set 13 | pattani
# Processing Record 14 of Set 13 | joao pinheiro
# Processing Record 15 of Set 13 | artyom
# Processing Record 16 of Set 13 | charters towers
# Processing Record 17 of Set 13 | hoquiam
# Processing Record 18 of Set 13 | jizan
# Processing Record 19 of Set 13 | kerki
# City not found. Skipping...
# Processing Record 20 of Set 13 | ken caryl
# Processing Record 21 of Set 13 | wake forest
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)


# Show Record Count
city_data_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   vilhena -12.7406  -60.1458     68.31        98         100        1.90
# 1  khatanga  71.9667  102.5000    -44.86        97          25        4.81
# 2   ushuaia -54.8000  -68.3000     44.26        93           0        4.61
# 3   fairlie  55.7560   -4.8556     47.17        88         100       10.00
# 4     bluff -46.6000  168.3333     57.79        70          16        6.98
#
#   Country        Date
# 0      BR  1676018251
# 1      RU  1676018255
# 2      AR  1676018255
# 3      GB  1676018260
# 4      NZ  1676018262

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         vilhena -12.7406  -60.1458     68.31        98         100
# 1        khatanga  71.9667  102.5000    -44.86        97          25
# 2         ushuaia -54.8000  -68.3000     44.26        93           0
# 3         fairlie  55.7560   -4.8556     47.17        88         100
# 4           bluff -46.6000  168.3333     57.79        70          16
#
#          Wind Speed Country        Date
# City_ID
# 0              1.90      BR  1676018251
# 1              4.81      RU  1676018255
# 2              4.61      AR  1676018255
# 3             10.00      GB  1676018260
# 4              6.98      NZ  1676018262

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker ='^', s=20, c='r', edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title('City Latitude vs Max Temp')
plt.ylabel('Max Temperature')
plt.xlabel('Latitude')
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'], marker ='^', s=20, c='r', edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title('City Latitude vs Humditity')
plt.ylabel('Humidity %')
plt.xlabel('Latitude')
plt.grid(True)

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'], marker ='^', s=20, c='r', edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title('City Latitude vs Cloudiness')
plt.ylabel('Cloudines %')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'], marker ='^', s=20, c='r', edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title('City Latitude vs Wind Speed')
plt.ylabel('Wind Speed mph')
plt.xlabel('Latitude')
plt.grid(True)
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

equation_line= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(equation_line)



# Add the linear regression equation and line to plot
fig1, ax1 = plt.subplots(figsize=(15, 10))
plt.scatter(x_values,y_values,s=175, color="blue")
plt.plot(x_values,regress_values,"r-")
plt.title('Max Temp vs Latitude',fontsize =20)
plt.xlabel('Latitude',fontsize =10)
plt.ylabel('',fontsize =10)


print(f"The r-squared is: {rvalue**2}")
# Out:
# y = -0.74x + 66.87
# The r-squared is: 0.5880090407410447

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi = city_data_df[city_data_df["Lat"]>=0]
northern_hemi_df = pd.DataFrame(northern_hemi)

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1          khatanga  71.9667  102.5000    -44.86        97          25
# 3           fairlie  55.7560   -4.8556     47.17        88         100
# 8            albany  42.6001  -73.9662     50.95        89          71
# 9            xining  36.6167  101.7667     43.74        13          39
# 11       whitehorse  60.7161 -135.0538     23.77        86          75
#
#          Wind Speed Country        Date
# City_ID
# 1              4.81      RU  1676018255
# 3             10.00      GB  1676018260
# 8              4.99      US  1676018174
# 9              2.53      CN  1676018266
# 11            18.41      CA  1676018173

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi = city_data_df[city_data_df["Lat"]<0]
southern_hemi_df = pd.DataFrame(southern_hemi)


# Display sample data
southern_hemi_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        vilhena -12.7406  -60.1458     68.31        98         100
# 2        ushuaia -54.8000  -68.3000     44.26        93           0
# 4          bluff -46.6000  168.3333     57.79        70          16
# 5        mataura -46.1927  168.8643     57.47        75          47
# 6           chuy -33.6971  -53.4616     66.54        89           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.90      BR  1676018251
# 2              4.61      AR  1676018255
# 4              6.98      NZ  1676018262
# 5              0.43      NZ  1676018263
# 6              1.97      UY  1676018264

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

equation_line= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(equation_line)
print(f"The r-squared is: {rvalue**2}")

plt.scatter(x_values,y_values, marker ='o', s=20, c='green', edgecolors='black', alpha=0.75)
plt.title('Northern Hemisphere: City Latitude vs Max Temp')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid(True)
plt.plot(x_values,regress_values,"r-")
plt.annotate(equation_line,(5.8,2), fontsize=15, color='b')
plt.show()
# Out:
# y = -1.44x + 97.9
# The r-squared is: 0.7429225488970789

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

equation_line= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(equation_line)
print(f"The r-squared is: {rvalue**2}")

plt.scatter(x_values,y_values, marker ='o', s=20, c='green', edgecolors='black', alpha=0.75)
plt.title('Southern Hemisphere: City Latitude vs Max Temp')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid(True)
plt.plot(x_values,regress_values,"r-")
plt.annotate(equation_line,(5.8,2), fontsize=15, color='b')
plt.show()
# Out:
# y = 0.37x + 83.25
# The r-squared is: 0.24646448880911376

# %% [markdown]
# **Discussion about the linear relationship:** The Northern Hemisphere has a  moderate relationship between Max Temp and Latitude of r value of 0.75. The Southern Hemisphere, is still has a weak relationship between Max Temp and Latitude value of r value of 0.21

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

equation_line= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(equation_line)
print(f"The r-squared is: {rvalue**2}")

plt.scatter(x_values,y_values, marker ='o', s=20, c='green', edgecolors='black', alpha=0.75)
plt.title('Northern Hemisphere: City Latitude vs Humidity')
plt.ylabel('Humidity %')
plt.xlabel('Latitude')
plt.grid(True)
plt.plot(x_values,regress_values,"r-")
plt.annotate(equation_line,(5.8,2), fontsize=15, color='b')
plt.show()
# Out:
# y = 0.49x + 54.04
# The r-squared is: 0.1845031158484051

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

equation_line= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(equation_line)
print(f"The r-squared is: {rvalue**2}")

plt.scatter(x_values,y_values, marker ='o', s=20, c='green', edgecolors='black', alpha=0.75)
plt.title('Southern Hemisphere: City Latitude vs Humidity')
plt.ylabel('Humidity %')
plt.xlabel('Latitude')
plt.grid(True)
plt.plot(x_values,regress_values,"r-")
plt.annotate(equation_line,(-40,20), fontsize=15, color='b')
plt.show()
# Out:
# y = 0.23x + 78.94
# The r-squared is: 0.026275301859057888

# %% [markdown]
# **Discussion about the linear relationship:** none the relationship is weak between the Latitude and Humidity based on the determined r-value for both southern and northern hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

equation_line= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(equation_line)
print(f"The r-squared is: {rvalue**2}")

plt.scatter(x_values,y_values, marker ='o', s=20, c='green', edgecolors='black', alpha=0.75)
plt.title('Northern Hemisphere: City Latitude vs Cloudiness')
plt.ylabel('Cloudiness %')
plt.xlabel('Latitude')
plt.grid(True)
plt.plot(x_values,regress_values,"r-")
plt.annotate(equation_line,(4.5,80), fontsize=15, color='b')
plt.show()
# Out:
# y = 0.67x + 32.56
# The r-squared is: 0.11294412040858291

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

equation_line= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(equation_line)
print(f"The r-squared is: {rvalue**2}")

plt.scatter(x_values,y_values, marker ='o', s=20, c='green', edgecolors='black', alpha=0.75)
plt.title('Southern Hemisphere: City Latitude vs Cloudiness')
plt.ylabel('Cloudiness %')
plt.xlabel('Latitude')
plt.grid(True)
plt.plot(x_values,regress_values,"r-")
plt.annotate(equation_line,(-40,25), fontsize=15, color='b')
plt.show()
# Out:
# y = 1.21x + 80.87
# The r-squared is: 0.16633210202039944

# %% [markdown]
# **Discussion about the linear relationship:** both graphs show no linear relationship between Latitude and cloudines

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

equation_line= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(equation_line)
print(f"The r-squared is: {rvalue**2}")

plt.scatter(x_values,y_values, marker ='o', s=20, c='green', edgecolors='black', alpha=0.75)
plt.title('Northern Hemisphere: City Latitude vs Wind Speed')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)
plt.plot(x_values,regress_values,"r-")
plt.annotate(equation_line,(5.8,40), fontsize=15, color='b')
plt.show()
# Out:
# y = 0.01x + 8.83
# The r-squared is: 0.0018973699428246208

# %%
# Southern Hemisphere

x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

equation_line= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(equation_line)
print(f"The r-squared is: {rvalue**2}")

plt.scatter(x_values,y_values, marker ='o', s=20, c='green', edgecolors='black', alpha=0.75)
plt.title('Southern Hemisphere: City Latitude vs Wind Speed')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)
plt.plot(x_values,regress_values,"r-")
plt.annotate(equation_line,(-40,25), fontsize=15, color='b')
plt.show()
# Out:
# y = -0.04x + 6.71
# The r-squared is: 0.009221732323602346

# %% [markdown]
# **Discussion about the linear relationship: No Relationship - The linear regresion shows a much lower correlation than it appears. There is no linear relationship between Latitude and Wind Speed. Based on the the r-value which are low.
