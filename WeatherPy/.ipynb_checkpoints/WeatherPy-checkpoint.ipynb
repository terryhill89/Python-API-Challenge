# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Import API key
from config import api_key 

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 622

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units ="imperial"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']["lat"]
        city_lng = city_weather['coord']["lon"]
        city_max_temp = city_weather['main']["temp_max"]
        city_humidity = city_weather['main']["humidity"]
        city_clouds = city_weather['clouds']["all"]
        city_wind = city_weather['wind']["speed"]
        city_country = city_weather['sys']["country"]
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | iqaluit
# Processing Record 2 of Set 1 | sept-iles
# Processing Record 3 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | saint george
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | beringovskiy
# Processing Record 8 of Set 1 | saskylakh
# Processing Record 9 of Set 1 | tezu
# Processing Record 10 of Set 1 | northam
# Processing Record 11 of Set 1 | hirara
# Processing Record 12 of Set 1 | norman wells
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | shar
# Processing Record 16 of Set 1 | westport
# Processing Record 17 of Set 1 | pilar
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | flin flon
# Processing Record 22 of Set 1 | gurskoye
# City not found. Skipping...
# Processing Record 23 of Set 1 | touros
# Processing Record 24 of Set 1 | luanda
# Processing Record 25 of Set 1 | rawson
# Processing Record 26 of Set 1 | kieta
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | san quintin
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | kasongo-lunda
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | college
# Processing Record 34 of Set 1 | viedma
# Processing Record 35 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 1 | hambantota
# Processing Record 37 of Set 1 | airai
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | hobyo
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | juba
# Processing Record 43 of Set 1 | pangnirtung
# Processing Record 44 of Set 1 | jaque
# Processing Record 45 of Set 1 | sisimiut
# Processing Record 46 of Set 1 | grand forks
# Processing Record 47 of Set 1 | atar
# Processing Record 48 of Set 1 | ostrovnoy
# Processing Record 49 of Set 1 | chokurdakh
# Processing Record 50 of Set 1 | abu samrah
# Processing Record 0 of Set 2 | nisia floresta
# Processing Record 1 of Set 2 | cutervo
# Processing Record 2 of Set 2 | upernavik
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | cherskiy
# Processing Record 5 of Set 2 | toora-khem
# Processing Record 6 of Set 2 | wahran
# City not found. Skipping...
# Processing Record 7 of Set 2 | cabo san lucas
# Processing Record 8 of Set 2 | girau do ponciano
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | khatanga
# Processing Record 11 of Set 2 | timbiqui
# Processing Record 12 of Set 2 | mana
# Processing Record 13 of Set 2 | saint-philippe
# Processing Record 14 of Set 2 | kahului
# Processing Record 15 of Set 2 | bahia blanca
# Processing Record 16 of Set 2 | matagami
# Processing Record 17 of Set 2 | mandalgovi
# Processing Record 18 of Set 2 | mashhad
# Processing Record 19 of Set 2 | hasaki
# Processing Record 20 of Set 2 | narsaq
# Processing Record 21 of Set 2 | acaponeta
# Processing Record 22 of Set 2 | lulea
# Processing Record 23 of Set 2 | tasiilaq
# Processing Record 24 of Set 2 | goulburn
# Processing Record 25 of Set 2 | srednekolymsk
# Processing Record 26 of Set 2 | taburao
# City not found. Skipping...
# Processing Record 27 of Set 2 | butaritari
# Processing Record 28 of Set 2 | taltal
# Processing Record 29 of Set 2 | tiarei
# Processing Record 30 of Set 2 | sao filipe
# Processing Record 31 of Set 2 | port elizabeth
# Processing Record 32 of Set 2 | yellowknife
# Processing Record 33 of Set 2 | hofn
# Processing Record 34 of Set 2 | puerto ayora
# Processing Record 35 of Set 2 | lusambo
# Processing Record 36 of Set 2 | ustye
# Processing Record 37 of Set 2 | mar del plata
# Processing Record 38 of Set 2 | dikson
# Processing Record 39 of Set 2 | sinnai
# Processing Record 40 of Set 2 | atuona
# Processing Record 41 of Set 2 | hermanus
# Processing Record 42 of Set 2 | sorland
# Processing Record 43 of Set 2 | agara
# Processing Record 44 of Set 2 | moindou
# Processing Record 45 of Set 2 | thompson
# Processing Record 46 of Set 2 | bytca
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | dingle
# Processing Record 49 of Set 2 | zyryanskoye
# Processing Record 0 of Set 3 | kirovsk
# Processing Record 1 of Set 3 | vestmannaeyjar
# Processing Record 2 of Set 3 | alofi
# Processing Record 3 of Set 3 | yumbo
# Processing Record 4 of Set 3 | fortuna
# Processing Record 5 of Set 3 | san policarpo
# Processing Record 6 of Set 3 | east london
# Processing Record 7 of Set 3 | aswan
# Processing Record 8 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 3 | bilma
# Processing Record 10 of Set 3 | puerto escondido
# Processing Record 11 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 3 | kaduna
# Processing Record 13 of Set 3 | souillac
# Processing Record 14 of Set 3 | mecca
# Processing Record 15 of Set 3 | kapaa
# Processing Record 16 of Set 3 | pisco
# Processing Record 17 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 3 | tabou
# Processing Record 19 of Set 3 | slavutych
# Processing Record 20 of Set 3 | calvinia
# Processing Record 21 of Set 3 | vila franca do campo
# Processing Record 22 of Set 3 | saryozek
# Processing Record 23 of Set 3 | new norfolk
# Processing Record 24 of Set 3 | hualmay
# Processing Record 25 of Set 3 | agadez
# Processing Record 26 of Set 3 | esperance
# Processing Record 27 of Set 3 | zhigansk
# Processing Record 28 of Set 3 | peniche
# Processing Record 29 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 30 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 3 | biak
# Processing Record 32 of Set 3 | hobart
# Processing Record 33 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 3 | monrovia
# Processing Record 35 of Set 3 | humaita
# Processing Record 36 of Set 3 | sobolevo
# Processing Record 37 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 3 | kirakira
# Processing Record 39 of Set 3 | naze
# Processing Record 40 of Set 3 | alta floresta
# Processing Record 41 of Set 3 | tuatapere
# Processing Record 42 of Set 3 | fort william
# Processing Record 43 of Set 3 | severo-kurilsk
# Processing Record 44 of Set 3 | pangai
# Processing Record 45 of Set 3 | karpathos
# Processing Record 46 of Set 3 | dekoa
# City not found. Skipping...
# Processing Record 47 of Set 3 | shimoda
# Processing Record 48 of Set 3 | roald
# Processing Record 49 of Set 3 | berlevag
# Processing Record 0 of Set 4 | voronovytsya
# Processing Record 1 of Set 4 | oktyabrskoye
# Processing Record 2 of Set 4 | piranshahr
# Processing Record 3 of Set 4 | kununurra
# Processing Record 4 of Set 4 | te anau
# Processing Record 5 of Set 4 | broome
# Processing Record 6 of Set 4 | nikolskoye
# Processing Record 7 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 4 | vardo
# Processing Record 9 of Set 4 | seymchan
# Processing Record 10 of Set 4 | carnarvon
# Processing Record 11 of Set 4 | avarua
# Processing Record 12 of Set 4 | nsanje
# Processing Record 13 of Set 4 | tevaitoa
# Processing Record 14 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 4 | vao
# Processing Record 16 of Set 4 | victoria
# Processing Record 17 of Set 4 | mugreyevskiy
# City not found. Skipping...
# Processing Record 18 of Set 4 | chapada dos guimaraes
# Processing Record 19 of Set 4 | iisalmi
# Processing Record 20 of Set 4 | sawakin
# Processing Record 21 of Set 4 | ancud
# Processing Record 22 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 4 | nelson bay
# Processing Record 24 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 4 | sitka
# Processing Record 26 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 27 of Set 4 | jizan
# Processing Record 28 of Set 4 | saint-pierre
# Processing Record 29 of Set 4 | laguna
# Processing Record 30 of Set 4 | bathsheba
# Processing Record 31 of Set 4 | tuktoyaktuk
# Processing Record 32 of Set 4 | anadyr
# Processing Record 33 of Set 4 | neftcala
# Processing Record 34 of Set 4 | korla
# Processing Record 35 of Set 4 | kismayo
# Processing Record 36 of Set 4 | mizan teferi
# Processing Record 37 of Set 4 | jalu
# Processing Record 38 of Set 4 | cidreira
# Processing Record 39 of Set 4 | smyrna
# Processing Record 40 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 4 | lagoa
# Processing Record 42 of Set 4 | barra patuca
# Processing Record 43 of Set 4 | karatau
# Processing Record 44 of Set 4 | cabedelo
# Processing Record 45 of Set 4 | ghanzi
# Processing Record 46 of Set 4 | poum
# Processing Record 47 of Set 4 | san patricio
# Processing Record 48 of Set 4 | qaanaaq
# Processing Record 49 of Set 4 | port-cartier
# Processing Record 0 of Set 5 | tura
# Processing Record 1 of Set 5 | torbay
# Processing Record 2 of Set 5 | jiujiang
# Processing Record 3 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 5 | ornskoldsvik
# Processing Record 5 of Set 5 | rio grande
# Processing Record 6 of Set 5 | newport
# Processing Record 7 of Set 5 | nanortalik
# Processing Record 8 of Set 5 | pevek
# Processing Record 9 of Set 5 | buraydah
# Processing Record 10 of Set 5 | vila
# Processing Record 11 of Set 5 | inta
# Processing Record 12 of Set 5 | marawi
# Processing Record 13 of Set 5 | cayenne
# Processing Record 14 of Set 5 | teyateyaneng
# Processing Record 15 of Set 5 | andenes
# Processing Record 16 of Set 5 | ust-kulom
# Processing Record 17 of Set 5 | kochki
# Processing Record 18 of Set 5 | ilulissat
# Processing Record 19 of Set 5 | itoman
# Processing Record 20 of Set 5 | port blair
# Processing Record 21 of Set 5 | kaeo
# Processing Record 22 of Set 5 | micheweni
# Processing Record 23 of Set 5 | carambei
# Processing Record 24 of Set 5 | lillooet
# Processing Record 25 of Set 5 | prieska
# Processing Record 26 of Set 5 | gizo
# Processing Record 27 of Set 5 | kiama
# Processing Record 28 of Set 5 | choma
# Processing Record 29 of Set 5 | onega
# Processing Record 30 of Set 5 | abu kamal
# Processing Record 31 of Set 5 | leeton
# Processing Record 32 of Set 5 | shreveport
# Processing Record 33 of Set 5 | malinyi
# Processing Record 34 of Set 5 | vaini
# Processing Record 35 of Set 5 | burkhala
# City not found. Skipping...
# Processing Record 36 of Set 5 | shelburne
# Processing Record 37 of Set 5 | shihezi
# Processing Record 38 of Set 5 | richards bay
# Processing Record 39 of Set 5 | havre-saint-pierre
# Processing Record 40 of Set 5 | kautokeino
# Processing Record 41 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 5 | thinadhoo
# Processing Record 43 of Set 5 | lebu
# Processing Record 44 of Set 5 | oksfjord
# Processing Record 45 of Set 5 | karuzi
# Processing Record 46 of Set 5 | bengkulu
# Processing Record 47 of Set 5 | akyab
# Processing Record 48 of Set 5 | walvis bay
# Processing Record 49 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 0 of Set 6 | los llanos de aridane
# Processing Record 1 of Set 6 | provideniya
# Processing Record 2 of Set 6 | howard springs
# Processing Record 3 of Set 6 | barra do bugres
# Processing Record 4 of Set 6 | port hardy
# Processing Record 5 of Set 6 | sabang
# Processing Record 6 of Set 6 | general roca
# Processing Record 7 of Set 6 | tilichiki
# Processing Record 8 of Set 6 | borovskoy
# Processing Record 9 of Set 6 | kodiak
# Processing Record 10 of Set 6 | filadelfia
# Processing Record 11 of Set 6 | grindavik
# Processing Record 12 of Set 6 | punto fijo
# Processing Record 13 of Set 6 | longyearbyen
# Processing Record 14 of Set 6 | amethi
# Processing Record 15 of Set 6 | kilindoni
# Processing Record 16 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 6 | mkuranga
# Processing Record 18 of Set 6 | santa maria
# Processing Record 19 of Set 6 | salinopolis
# Processing Record 20 of Set 6 | praia da vitoria
# Processing Record 21 of Set 6 | kidal
# Processing Record 22 of Set 6 | bac lieu
# Processing Record 23 of Set 6 | patnos
# Processing Record 24 of Set 6 | chuy
# Processing Record 25 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 6 | taiyuan
# Processing Record 27 of Set 6 | bambous virieux
# Processing Record 28 of Set 6 | leningradskiy
# Processing Record 29 of Set 6 | aligudarz
# Processing Record 30 of Set 6 | kabinda
# Processing Record 31 of Set 6 | evensk
# Processing Record 32 of Set 6 | braganca
# Processing Record 33 of Set 6 | oyem
# Processing Record 34 of Set 6 | gobabis
# Processing Record 35 of Set 6 | necochea
# Processing Record 36 of Set 6 | strezhevoy
# Processing Record 37 of Set 6 | saint anthony
# Processing Record 38 of Set 6 | coihaique
# Processing Record 39 of Set 6 | el faiyum
# City not found. Skipping...
# Processing Record 40 of Set 6 | guerrero negro
# Processing Record 41 of Set 6 | ribeira grande
# Processing Record 42 of Set 6 | virtsu
# Processing Record 43 of Set 6 | plavsk
# Processing Record 44 of Set 6 | ambon
# Processing Record 45 of Set 6 | uruzgan
# Processing Record 46 of Set 6 | horodyshche
# Processing Record 47 of Set 6 | migori
# Processing Record 48 of Set 6 | kaka
# Processing Record 49 of Set 6 | kijang
# Processing Record 0 of Set 7 | farap
# Processing Record 1 of Set 7 | los corrales de buelna
# Processing Record 2 of Set 7 | conceicao do araguaia
# Processing Record 3 of Set 7 | tucurui
# Processing Record 4 of Set 7 | chifeng
# Processing Record 5 of Set 7 | skjervoy
# Processing Record 6 of Set 7 | margate
# Processing Record 7 of Set 7 | mount isa
# Processing Record 8 of Set 7 | itaocara
# Processing Record 9 of Set 7 | sasaram
# Processing Record 10 of Set 7 | cooma
# Processing Record 11 of Set 7 | faanui
# Processing Record 12 of Set 7 | topolobampo
# Processing Record 13 of Set 7 | trorod
# Processing Record 14 of Set 7 | namibe
# Processing Record 15 of Set 7 | balakhninskiy
# Processing Record 16 of Set 7 | bontang
# Processing Record 17 of Set 7 | cabanbanan
# Processing Record 18 of Set 7 | alcazar de san juan
# Processing Record 19 of Set 7 | dubreka
# Processing Record 20 of Set 7 | talnakh
# Processing Record 21 of Set 7 | lavrentiya
# Processing Record 22 of Set 7 | betioky
# Processing Record 23 of Set 7 | isangel
# Processing Record 24 of Set 7 | arman
# Processing Record 25 of Set 7 | rio claro
# Processing Record 26 of Set 7 | taoudenni
# Processing Record 27 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 7 | steamboat springs
# Processing Record 29 of Set 7 | mehamn
# Processing Record 30 of Set 7 | kavieng
# Processing Record 31 of Set 7 | baleshwar
# Processing Record 32 of Set 7 | tiksi
# Processing Record 33 of Set 7 | saldanha
# Processing Record 34 of Set 7 | mahebourg
# Processing Record 35 of Set 7 | dekar
# Processing Record 36 of Set 7 | bandarbeyla
# Processing Record 37 of Set 7 | roma
# Processing Record 38 of Set 7 | ixtapa
# Processing Record 39 of Set 7 | brainerd
# Processing Record 40 of Set 7 | tazmalt
# Processing Record 41 of Set 7 | aklavik
# Processing Record 42 of Set 7 | chulman
# Processing Record 43 of Set 7 | vanimo
# Processing Record 44 of Set 7 | matara
# Processing Record 45 of Set 7 | urucara
# Processing Record 46 of Set 7 | marquette
# Processing Record 47 of Set 7 | clyde river
# Processing Record 48 of Set 7 | lompoc
# Processing Record 49 of Set 7 | kayerkan
# Processing Record 0 of Set 8 | robertsport
# Processing Record 1 of Set 8 | bonavista
# Processing Record 2 of Set 8 | yefremov
# Processing Record 3 of Set 8 | bonito
# Processing Record 4 of Set 8 | seoul
# Processing Record 5 of Set 8 | jumla
# Processing Record 6 of Set 8 | la ronge
# Processing Record 7 of Set 8 | georgetown
# Processing Record 8 of Set 8 | ponta do sol
# Processing Record 9 of Set 8 | smithers
# Processing Record 10 of Set 8 | shingu
# Processing Record 11 of Set 8 | nagato
# Processing Record 12 of Set 8 | goderich
# Processing Record 13 of Set 8 | san juan
# Processing Record 14 of Set 8 | mullaitivu
# City not found. Skipping...
# Processing Record 15 of Set 8 | ulladulla
# Processing Record 16 of Set 8 | liku
# Processing Record 17 of Set 8 | naqadeh
# Processing Record 18 of Set 8 | arlit
# Processing Record 19 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 20 of Set 8 | saint-georges
# Processing Record 21 of Set 8 | constitucion
# Processing Record 22 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 23 of Set 8 | macau
# Processing Record 24 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 25 of Set 8 | mount darwin
# Processing Record 26 of Set 8 | uaua
# Processing Record 27 of Set 8 | mogwase
# Processing Record 28 of Set 8 | changde
# Processing Record 29 of Set 8 | sinnamary
# Processing Record 30 of Set 8 | tecolutilla
# Processing Record 31 of Set 8 | fare
# Processing Record 32 of Set 8 | belaya gora
# Processing Record 33 of Set 8 | biltine
# Processing Record 34 of Set 8 | erbiceni
# Processing Record 35 of Set 8 | basco
# Processing Record 36 of Set 8 | ormara
# Processing Record 37 of Set 8 | kuching
# Processing Record 38 of Set 8 | geraldton
# Processing Record 39 of Set 8 | takaka
# Processing Record 40 of Set 8 | yarada
# Processing Record 41 of Set 8 | grebenskaya
# Processing Record 42 of Set 8 | hamilton
# Processing Record 43 of Set 8 | maragogi
# Processing Record 44 of Set 8 | haines junction
# Processing Record 45 of Set 8 | thunder bay
# Processing Record 46 of Set 8 | mount gambier
# Processing Record 47 of Set 8 | charlottetown
# Processing Record 48 of Set 8 | half moon bay
# Processing Record 49 of Set 8 | eugene
# Processing Record 0 of Set 9 | labrea
# Processing Record 1 of Set 9 | arkhangelsk
# Processing Record 2 of Set 9 | puerto leguizamo
# Processing Record 3 of Set 9 | talaya
# Processing Record 4 of Set 9 | yeletskiy
# City not found. Skipping...
# Processing Record 5 of Set 9 | jonesboro
# Processing Record 6 of Set 9 | nyurba
# Processing Record 7 of Set 9 | lagunas
# Processing Record 8 of Set 9 | mahmudia
# Processing Record 9 of Set 9 | jalalabad
# Processing Record 10 of Set 9 | waipawa
# Processing Record 11 of Set 9 | abiy adi
# City not found. Skipping...
# Processing Record 12 of Set 9 | elizabeth city
# Processing Record 13 of Set 9 | beira
# Processing Record 14 of Set 9 | erzin
# Processing Record 15 of Set 9 | axixa do tocantins
# City not found. Skipping...
# Processing Record 16 of Set 9 | yumen
# Processing Record 17 of Set 9 | champerico
# Processing Record 18 of Set 9 | arcoverde
# Processing Record 19 of Set 9 | luderitz
# Processing Record 20 of Set 9 | vostok
# Processing Record 21 of Set 9 | niamey
# Processing Record 22 of Set 9 | puerto colombia
# Processing Record 23 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 9 | fairbanks
# Processing Record 25 of Set 9 | timizart
# Processing Record 26 of Set 9 | koshurnikovo
# Processing Record 27 of Set 9 | shakawe
# Processing Record 28 of Set 9 | buala
# Processing Record 29 of Set 9 | salalah
# Processing Record 30 of Set 9 | saravan
# Processing Record 31 of Set 9 | abnub
# Processing Record 32 of Set 9 | innisfail
# Processing Record 33 of Set 9 | bonthe
# Processing Record 34 of Set 9 | portland
# Processing Record 35 of Set 9 | kamiiso
# Processing Record 36 of Set 9 | padang
# Processing Record 37 of Set 9 | road town
# Processing Record 38 of Set 9 | itaituba
# Processing Record 39 of Set 9 | north bend
# Processing Record 40 of Set 9 | nome
# Processing Record 41 of Set 9 | copiapo
# Processing Record 42 of Set 9 | russell
# Processing Record 43 of Set 9 | eureka
# Processing Record 44 of Set 9 | birao
# Processing Record 45 of Set 9 | hami
# Processing Record 46 of Set 9 | lianran
# Processing Record 47 of Set 9 | saint-augustin
# Processing Record 48 of Set 9 | vikulovo
# Processing Record 49 of Set 9 | kadaya
# Processing Record 0 of Set 10 | ahipara
# Processing Record 1 of Set 10 | nantucket
# Processing Record 2 of Set 10 | sao jose da coroa grande
# Processing Record 3 of Set 10 | mayo
# Processing Record 4 of Set 10 | faya
# Processing Record 5 of Set 10 | nadym
# Processing Record 6 of Set 10 | galveston
# Processing Record 7 of Set 10 | adrar
# Processing Record 8 of Set 10 | porto santo
# Processing Record 9 of Set 10 | ishinomaki
# Processing Record 10 of Set 10 | dingwall
# Processing Record 11 of Set 10 | bardiyah
# Processing Record 12 of Set 10 | basse
# Processing Record 13 of Set 10 | otradnoye
# Processing Record 14 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 10 | gustrow
# Processing Record 16 of Set 10 | avdon
# Processing Record 17 of Set 10 | tautira
# Processing Record 18 of Set 10 | talas
# Processing Record 19 of Set 10 | batemans bay
# Processing Record 20 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 10 | sioux lookout
# Processing Record 22 of Set 10 | kargopol
# Processing Record 23 of Set 10 | martapura
# Processing Record 24 of Set 10 | mabaruma
# Processing Record 25 of Set 10 | ovre ardal
# Processing Record 26 of Set 10 | porto novo
# Processing Record 27 of Set 10 | castelo branco
# Processing Record 28 of Set 10 | tsabong
# Processing Record 29 of Set 10 | kaitangata
# Processing Record 30 of Set 10 | deputatskiy
# Processing Record 31 of Set 10 | dubbo
# Processing Record 32 of Set 10 | sikasso
# Processing Record 33 of Set 10 | koungou
# Processing Record 34 of Set 10 | yar-sale
# Processing Record 35 of Set 10 | kaptanganj
# Processing Record 36 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 10 | rocha
# Processing Record 38 of Set 10 | muli
# Processing Record 39 of Set 10 | port-gentil
# Processing Record 40 of Set 10 | udachnyy
# Processing Record 41 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 42 of Set 10 | huron
# Processing Record 43 of Set 10 | kutum
# Processing Record 44 of Set 10 | destin
# Processing Record 45 of Set 10 | excelsior springs
# Processing Record 46 of Set 10 | kissidougou
# Processing Record 47 of Set 10 | avera
# Processing Record 48 of Set 10 | oussouye
# Processing Record 49 of Set 10 | sangar
# Processing Record 0 of Set 11 | turayf
# Processing Record 1 of Set 11 | doha
# Processing Record 2 of Set 11 | lodja
# Processing Record 3 of Set 11 | chodziez
# Processing Record 4 of Set 11 | manzil jamil
# City not found. Skipping...
# Processing Record 5 of Set 11 | dzhebariki-khaya
# Processing Record 6 of Set 11 | muzaffarabad
# Processing Record 7 of Set 11 | new ulm
# Processing Record 8 of Set 11 | wanning
# Processing Record 9 of Set 11 | bahia honda
# Processing Record 10 of Set 11 | kingori
# Processing Record 11 of Set 11 | dunmore
# Processing Record 12 of Set 11 | jijiang
# Processing Record 13 of Set 11 | santa cruz
# Processing Record 14 of Set 11 | lima
# Processing Record 15 of Set 11 | dudinka
# Processing Record 16 of Set 11 | saint-paul
# Processing Record 17 of Set 11 | opuwo
# Processing Record 18 of Set 11 | salta
# Processing Record 19 of Set 11 | ekhabi
# Processing Record 20 of Set 11 | neuquen
# Processing Record 21 of Set 11 | sao gabriel da cachoeira
# Processing Record 22 of Set 11 | acapulco
# Processing Record 23 of Set 11 | axim
# Processing Record 24 of Set 11 | morant bay
# Processing Record 25 of Set 11 | bengkalis
# City not found. Skipping...
# Processing Record 26 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 11 | staffanstorp
# Processing Record 28 of Set 11 | monamon
# Processing Record 29 of Set 11 | colac
# Processing Record 30 of Set 11 | sola
# Processing Record 31 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 32 of Set 11 | coquimbo
# Processing Record 33 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 11 | beatrice
# Processing Record 35 of Set 11 | kudahuvadhoo
# Processing Record 36 of Set 11 | santa lucia
# Processing Record 37 of Set 11 | poso
# Processing Record 38 of Set 11 | dehloran
# Processing Record 39 of Set 11 | verkhnevilyuysk
# Processing Record 40 of Set 11 | dukuhturi
# Processing Record 41 of Set 11 | catamarca
# Processing Record 42 of Set 11 | baghdad
# Processing Record 43 of Set 11 | krasnaya gora
# Processing Record 44 of Set 11 | luebo
# Processing Record 45 of Set 11 | tignere
# Processing Record 46 of Set 11 | holsted
# Processing Record 47 of Set 11 | neyshabur
# Processing Record 48 of Set 11 | kem
# Processing Record 49 of Set 11 | humberto de campos
# Processing Record 0 of Set 12 | launceston
# Processing Record 1 of Set 12 | uray
# Processing Record 2 of Set 12 | gari
# Processing Record 3 of Set 12 | astoria
# Processing Record 4 of Set 12 | joao pinheiro
# Processing Record 5 of Set 12 | tecoanapa
# Processing Record 6 of Set 12 | batagay-alyta
# Processing Record 7 of Set 12 | pundaguitan
# Processing Record 8 of Set 12 | macara
# Processing Record 9 of Set 12 | kandiari
# Processing Record 10 of Set 12 | diffa
# Processing Record 11 of Set 12 | iskilip
# Processing Record 12 of Set 12 | morondava
# Processing Record 13 of Set 12 | waw
# Processing Record 14 of Set 12 | conop
# Processing Record 15 of Set 12 | metu
# Processing Record 16 of Set 12 | jiblah
# Processing Record 17 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 12 | kuybyshevo
# Processing Record 19 of Set 12 | massakory
# Processing Record 20 of Set 12 | port moresby
# Processing Record 21 of Set 12 | rovaniemi
# Processing Record 22 of Set 12 | trogir
# Processing Record 23 of Set 12 | pangody
# Processing Record 24 of Set 12 | the pas
# Processing Record 25 of Set 12 | kruisfontein
# Processing Record 26 of Set 12 | pangkalanbuun
# Processing Record 27 of Set 12 | mayumba
# Processing Record 28 of Set 12 | chapais
# Processing Record 29 of Set 12 | kharan
# Processing Record 30 of Set 12 | brokopondo
# Processing Record 31 of Set 12 | japura
# Processing Record 32 of Set 12 | henties bay
# Processing Record 33 of Set 12 | sur
# Processing Record 34 of Set 12 | lev tolstoy
# Processing Record 35 of Set 12 | cervantes
# Processing Record 36 of Set 12 | ostersund
# Processing Record 37 of Set 12 | tsienyane
# City not found. Skipping...
# Processing Record 38 of Set 12 | carutapera
# Processing Record 39 of Set 12 | mayen
# Processing Record 40 of Set 12 | aktau
# Processing Record 41 of Set 12 | vila velha
# Processing Record 42 of Set 12 | kavaratti
# Processing Record 43 of Set 12 | waling
# Processing Record 44 of Set 12 | imbituba
# Processing Record 45 of Set 12 | klaksvik
# Processing Record 46 of Set 12 | pindiga
# Processing Record 47 of Set 12 | markova
# Processing Record 48 of Set 12 | husavik
# Processing Record 49 of Set 12 | lhuntshi
# City not found. Skipping...
# Processing Record 0 of Set 13 | tutoia
# Processing Record 1 of Set 13 | marsabit
# Processing Record 2 of Set 13 | palkino
# Processing Record 3 of Set 13 | yinchuan
# Processing Record 4 of Set 13 | gondanglegi
# Processing Record 5 of Set 13 | ust-kuyga
# Processing Record 6 of Set 13 | mao
# Processing Record 7 of Set 13 | linshui
# Processing Record 8 of Set 13 | tukrah
# Processing Record 9 of Set 13 | rincon
# Processing Record 10 of Set 13 | sistranda
# Processing Record 11 of Set 13 | antalaha
# Processing Record 12 of Set 13 | kamaishi
# Processing Record 13 of Set 13 | north platte
# Processing Record 14 of Set 13 | klyuchi
# Processing Record 15 of Set 13 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 17 of Set 13 | kristiansund
# Processing Record 18 of Set 13 | peleduy
# Processing Record 19 of Set 13 | antofagasta
# Processing Record 20 of Set 13 | ust-uda
# Processing Record 21 of Set 13 | bali
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)


# Show Record Count
city_data_df.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       iqaluit  63.7506  -68.5145    -29.31        66           0
# 1     sept-iles  50.2001  -66.3821      6.80        66         100
# 2   port alfred -33.5906   26.8910     74.17        79          85
# 3  saint george  37.1041 -113.5841     36.95        48           0
# 4        barrow  71.2906 -156.7887    -14.78        76         100
#
#    Wind Speed Country        Date
# 0       11.50      CA  1676016960
# 1        9.22      CA  1676016961
# 2        3.00      ZA  1676016963
# 3        3.44      US  1676016856
# 4        3.44      US  1676016968

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             iqaluit  63.7506  -68.5145    -29.31        66           0
# 1           sept-iles  50.2001  -66.3821      6.80        66         100
# 2         port alfred -33.5906   26.8910     74.17        79          85
# 3        saint george  37.1041 -113.5841     36.95        48           0
# 4              barrow  71.2906 -156.7887    -14.78        76         100
#
#          Wind Speed Country        Date
# City_ID
# 0             11.50      CA  1676016960
# 1              9.22      CA  1676016961
# 2              3.00      ZA  1676016963
# 3              3.44      US  1676016856
# 4              3.44      US  1676016968

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker ='^', s=20, c='r', edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title('City Latitude vs Max Temp')
plt.ylabel('Max Temperature')
plt.xlabel('Latitude')
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'], marker ='^', s=20, c='r', edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title('City Latitude vs Humditity')
plt.ylabel('Humidity %')
plt.xlabel('Latitude')
plt.grid(True)

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'], marker ='^', s=20, c='r', edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title('City Latitude vs Cloudiness')
plt.ylabel('Cloudines %')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'], marker ='^', s=20, c='r', edgecolors='black', alpha=0.75)

# Incorporate the other graph properties
plt.title('City Latitude vs Wind Speed')
plt.ylabel('Wind Speed mph')
plt.xlabel('Latitude')
plt.grid(True)
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

equation_line= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(equation_line)



# Add the linear regression equation and line to plot
fig1, ax1 = plt.subplots(figsize=(15, 10))
plt.scatter(x_values,y_values,s=175, color="blue")
plt.plot(x_values,regress_values,"r-")
plt.title('Max Temp vs Latitude',fontsize =20)
plt.xlabel('Latitude',fontsize =10)
plt.ylabel('',fontsize =10)


print(f"The r-squared is: {rvalue**2}")
# Out:
# y = -0.75x + 66.11
# The r-squared is: 0.5986178927667846

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi = city_data_df[city_data_df["Lat"]>=0]
northern_hemi_df = pd.DataFrame(northern_hemi)

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             iqaluit  63.7506  -68.5145    -29.31        66           0
# 1           sept-iles  50.2001  -66.3821      6.80        66         100
# 3        saint george  37.1041 -113.5841     36.95        48           0
# 4              barrow  71.2906 -156.7887    -14.78        76         100
# 5        beringovskiy  63.0500  179.3167    -24.97        96          92
#
#          Wind Speed Country        Date
# City_ID
# 0             11.50      CA  1676016960
# 1              9.22      CA  1676016961
# 3              3.44      US  1676016856
# 4              3.44      US  1676016968
# 5             10.20      RU  1676016971

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi = city_data_df[city_data_df["Lat"]<0]
southern_hemi_df = pd.DataFrame(southern_hemi)


# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        port alfred -33.5906   26.8910     74.17        79          85
# 12         busselton -33.6500  115.3333     75.20        57           5
# 15             pilar  -9.5972  -35.9567     73.33        92          79
# 16        bredasdorp -34.5322   20.0403     77.54        60          32
# 17         cape town -33.9258   18.4232     85.12        53           0
#
#          Wind Speed Country        Date
# City_ID
# 2              3.00      ZA  1676016963
# 12            18.61      AU  1676016987
# 15             2.84      BR  1676016991
# 16            15.66      ZA  1676016488
# 17            13.80      ZA  1676016178

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

equation_line= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(equation_line)
print(f"The r-squared is: {rvalue**2}")

plt.scatter(x_values,y_values, marker ='o', s=20, c='green', edgecolors='black', alpha=0.75)
plt.title('Northern Hemisphere: City Latitude vs Max Temp')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid(True)
plt.plot(x_values,regress_values,"r-")
plt.annotate(equation_line,(5.8,2), fontsize=15, color='b')
plt.show()
# Out:
# y = -1.42x + 95.76
# The r-squared is: 0.7388909463686277

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

equation_line= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(equation_line)
print(f"The r-squared is: {rvalue**2}")

plt.scatter(x_values,y_values, marker ='o', s=20, c='green', edgecolors='black', alpha=0.75)
plt.title('Southern Hemisphere: City Latitude vs Max Temp')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid(True)
plt.plot(x_values,regress_values,"r-")
plt.annotate(equation_line,(5.8,2), fontsize=15, color='b')
plt.show()
# Out:
# y = 0.34x + 82.19
# The r-squared is: 0.2418269999718646

# %% [markdown]
# **Discussion about the linear relationship:** The Northern Hemisphere has a  moderate relationship between Max Temp and Latitude of r value of 0.75. The Southern Hemisphere, is still has a weak relationship between Max Temp and Latitude value of r value of 0.21

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

equation_line= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(equation_line)
print(f"The r-squared is: {rvalue**2}")

plt.scatter(x_values,y_values, marker ='o', s=20, c='green', edgecolors='black', alpha=0.75)
plt.title('Northern Hemisphere: City Latitude vs Humidity')
plt.ylabel('Humidity %')
plt.xlabel('Latitude')
plt.grid(True)
plt.plot(x_values,regress_values,"r-")
plt.annotate(equation_line,(5.8,2), fontsize=15, color='b')
plt.show()
# Out:
# y = 0.55x + 51.01
# The r-squared is: 0.21961800114962005

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

equation_line= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(equation_line)
print(f"The r-squared is: {rvalue**2}")

plt.scatter(x_values,y_values, marker ='o', s=20, c='green', edgecolors='black', alpha=0.75)
plt.title('Southern Hemisphere: City Latitude vs Humidity')
plt.ylabel('Humidity %')
plt.xlabel('Latitude')
plt.grid(True)
plt.plot(x_values,regress_values,"r-")
plt.annotate(equation_line,(-40,20), fontsize=15, color='b')
plt.show()
# Out:
# y = 0.26x + 79.1
# The r-squared is: 0.03862454197253259

# %% [markdown]
# **Discussion about the linear relationship:** none the relationship is weak between the Latitude and Humidity based on the determined r-value for both southern and northern hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

equation_line= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(equation_line)
print(f"The r-squared is: {rvalue**2}")

plt.scatter(x_values,y_values, marker ='o', s=20, c='green', edgecolors='black', alpha=0.75)
plt.title('Northern Hemisphere: City Latitude vs Cloudiness')
plt.ylabel('Cloudiness %')
plt.xlabel('Latitude')
plt.grid(True)
plt.plot(x_values,regress_values,"r-")
plt.annotate(equation_line,(4.5,80), fontsize=15, color='b')
plt.show()
# Out:
# y = 0.78x + 27.89
# The r-squared is: 0.15200868082612762

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

equation_line= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(equation_line)
print(f"The r-squared is: {rvalue**2}")

plt.scatter(x_values,y_values, marker ='o', s=20, c='green', edgecolors='black', alpha=0.75)
plt.title('Southern Hemisphere: City Latitude vs Cloudiness')
plt.ylabel('Cloudiness %')
plt.xlabel('Latitude')
plt.grid(True)
plt.plot(x_values,regress_values,"r-")
plt.annotate(equation_line,(-40,25), fontsize=15, color='b')
plt.show()
# Out:
# y = 0.96x + 75.54
# The r-squared is: 0.11273007377662592

# %% [markdown]
# **Discussion about the linear relationship:** both graphs show no linear relationship between Latitude and cloudines

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

equation_line= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(equation_line)
print(f"The r-squared is: {rvalue**2}")

plt.scatter(x_values,y_values, marker ='o', s=20, c='green', edgecolors='black', alpha=0.75)
plt.title('Northern Hemisphere: City Latitude vs Wind Speed')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)
plt.plot(x_values,regress_values,"r-")
plt.annotate(equation_line,(5.8,40), fontsize=15, color='b')
plt.show()
# Out:
# y = 0.02x + 8.72
# The r-squared is: 0.0031818895281587023

# %%
# Southern Hemisphere

x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

equation_line= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(equation_line)
print(f"The r-squared is: {rvalue**2}")

plt.scatter(x_values,y_values, marker ='o', s=20, c='green', edgecolors='black', alpha=0.75)
plt.title('Southern Hemisphere: City Latitude vs Wind Speed')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)
plt.plot(x_values,regress_values,"r-")
plt.annotate(equation_line,(-40,25), fontsize=15, color='b')
plt.show()
# Out:
# y = -0.04x + 6.26
# The r-squared is: 0.011148252732217125

# %% [markdown]
# **Discussion about the linear relationship: No Relationship - The linear regresion shows a much lower correlation than it appears. There is no linear relationship between Latitude and Wind Speed. Based on the the r-value which are low.
